# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
adatok = pd.read_csv("/content/drive/MyDrive/datasets/cs-training.csv")

adatok.head()
# Out:
#    Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0           1                 1                              0.766127   45
# 1           2                 0                              0.957151   40
# 2           3                 0                              0.658180   38
# 3           4                 0                              0.233810   30
# 4           5                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# ...

# %%
adatok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101503 entries, 0 to 101502
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Unnamed: 0                            101503 non-null  int64
#  1   SeriousDlqin2yrs                      0 non-null       float64
#  2   RevolvingUtilizationOfUnsecuredLines  101503 non-null  float64
#  3   age                                   101503 non-null  int64
#  4   NumberOfTime30-59DaysPastDueNotWorse  101503 non-null  int64
#  5   DebtRatio                             101503 non-null  float64
#  6   MonthlyIncome                         81400 non-null   float64
#  7   NumberOfOpenCreditLinesAndLoans       101503 non-null  int64
#  8   NumberOfTimes90DaysLate               101503 non-null  int64
#  9   NumberRealEstateLoansOrLines          101503 non-null  int64
# ...

# %%
adatok.describe()
# Out:
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  150000.000000     150000.000000                         150000.000000
# mean    75000.500000          0.066840                              6.048438
# std     43301.414527          0.249746                            249.755371
# min         1.000000          0.000000                              0.000000
# 25%     37500.750000          0.000000                              0.029867
# 50%     75000.500000          0.000000                              0.154181
# 75%    112500.250000          0.000000                              0.559046
# max    150000.000000          1.000000                          50708.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  150000.000000                         150000.000000  150000.000000
# mean       52.295207                              0.421033     353.005076
# ...

# %%
adatok.rename(columns = {adatok.columns[0]:"Azon"}, inplace = True)
adatok.describe()
# Out:
#                 Azon  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  150000.000000     150000.000000                         150000.000000
# mean    75000.500000          0.066840                              6.048438
# std     43301.414527          0.249746                            249.755371
# min         1.000000          0.000000                              0.000000
# 25%     37500.750000          0.000000                              0.029867
# 50%     75000.500000          0.000000                              0.154181
# 75%    112500.250000          0.000000                              0.559046
# max    150000.000000          1.000000                          50708.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  150000.000000                         150000.000000  150000.000000
# mean       52.295207                              0.421033     353.005076
# ...

# %%
adatok.shape
# Out:
# (150000, 12)

# %%
adatok.drop(adatok.columns[[4, 8, 10]], axis = 1, inplace=True)
adatok.head(10)
# Out:
#    Azon  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0     1                 1                              0.766127   45
# 1     2                 0                              0.957151   40
# 2     3                 0                              0.658180   38
# 3     4                 0                              0.233810   30
# 4     5                 0                              0.907239   49
# 5     6                 0                              0.213179   74
# 6     7                 0                              0.305682   57
# 7     8                 0                              0.754464   39
# 8     9                 0                              0.116951   27
# 9    10                 0                              0.189169   57
#
#      DebtRatio  MonthlyIncome  NumberOfOpenCreditLinesAndLoans  \
# 0     0.802982         9120.0                               13
# 1     0.121876         2600.0                                4
# ...

# %%
adatok.shape
# Out:
# (150000, 9)

# %%
P = adatok.groupby('SeriousDlqin2yrs')['Azon'].count().reset_index()

P['Percentage'] = 100 * P['Azon']  / P['Azon'].sum()

print(P)
# Out:
#    SeriousDlqin2yrs    Azon  Percentage
# 0                 0  139974      93.316
# 1                 1   10026       6.684

# %%
adatok['RevolvingUtilizationOfUnsecuredLines'].describe()
# Out:
# count    150000.000000
# mean          6.048438
# std         249.755371
# min           0.000000
# 25%           0.029867
# 50%           0.154181
# 75%           0.559046
# max       50708.000000
# Name: RevolvingUtilizationOfUnsecuredLines, dtype: float64

# %%
adatok['RevolvingUtilizationOfUnsecuredLines'].fillna(method='ffill', inplace=True)
adatok['RevolvingUtilizationOfUnsecuredLines'].describe()
# Out:
# count    150000.000000
# mean          6.048438
# std         249.755371
# min           0.000000
# 25%           0.029867
# 50%           0.154181
# 75%           0.559046
# max       50708.000000
# Name: RevolvingUtilizationOfUnsecuredLines, dtype: float64

# %%
adatok['age'].describe()
# Out:
# count    150000.000000
# mean         52.295207
# std          14.771866
# min           0.000000
# 25%          41.000000
# 50%          52.000000
# 75%          63.000000
# max         109.000000
# Name: age, dtype: float64

# %%
adatok.nlargest(10, 'age')
adatok.nsmallest(10, 'age')
# Out:
#         Azon  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 65695  65696                 0                              1.000000    0
# 1731    1732                 0                              0.369472   21
# 2791    2792                 0                              1.000000   21
# 3368    3369                 0                              1.000000   21
# 3716    3717                 0                              1.000000   21
# 4417    4418                 0                              1.000000   21
# 4705    4706                 0                              1.000000   21
# 4816    4817                 0                              1.000000   21
# 5343    5344                 0                              1.000000   21
# 7687    7688                 1                              1.000000   21
#
#        DebtRatio  MonthlyIncome  NumberOfOpenCreditLinesAndLoans  \
# 65695   0.436927         6000.0                                6
# ...

# %%
adatok.loc[adatok.age > 80, 'age'] = np.nan
adatok.loc[adatok.age < 18, 'age'] = np.nan

# %%
adatok.isnull()
# Out:
#          Azon  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines    age  \
# 0       False             False                                 False  False
# 1       False             False                                 False  False
# 2       False             False                                 False  False
# 3       False             False                                 False  False
# 4       False             False                                 False  False
# ...       ...               ...                                   ...    ...
# 149995  False             False                                 False  False
# 149996  False             False                                 False  False
# 149997  False             False                                 False  False
# 149998  False             False                                 False  False
# 149999  False             False                                 False  False
#
# ...

# %%
len(adatok[adatok.isnull().any(1)==True].index.tolist())
# Out:
# <ipython-input-19-ae7e6507ec8b>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   len(adatok[adatok.isnull().any(1)==True].index.tolist())
# 32840

# %%
adatok[adatok['age'].isnull()].index.tolist()
adatok.age.replace(np.nan, 'unknown', inplace=True)
